# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
economy = pd.read_csv('Economy.csv')

# %%
economy.head()
# Out:
#          City State  Percent unemployment  State sale tax rate  \
# 0     Atlanta    GA                  10.2                0.040
# 1      Austin    TX                   6.3                0.063
# 2   Baltimore    MD                  11.1                0.060
# 3  Birmingham    AL                   NaN                4.050
# 4      Boston    MA                   6.6                0.063
#
#    Local tax rate  Total rate  Median Income  AvgTuition
# 0           0.049       0.089        59345.0     10309.0
# 1           0.020       0.083        65886.0      8729.0
# 2           0.000       0.060        50492.0     12273.0
# 3           0.060       0.100            NaN         NaN
# 4           0.000       0.063        62180.0     20442.0

# %%
economy.dtypes
# Out:
# City                     object
# State                    object
# Percent unemployment    float64
# State sale tax rate     float64
# Local tax rate          float64
# Total rate              float64
# Median Income           float64
# AvgTuition              float64
# dtype: object

# %%
economy['Rank_Unemployment'] = economy['Percent unemployment'].rank(ascending = 1)
economy['Rank_Sales'] = economy['Local tax rate'].rank(ascending = 1)
economy['Rank_income'] = economy['Median Income'].rank(ascending = 1) 
economy['Rank_Tution'] = economy['AvgTuition'].rank(ascending = 0)
economy.head()
# Out:
#          City State  Percent unemployment  State sale tax rate  \
# 0     Atlanta    GA                  10.2                0.040
# 1      Austin    TX                   6.3                0.063
# 2   Baltimore    MD                  11.1                0.060
# 3  Birmingham    AL                   NaN                4.050
# 4      Boston    MA                   6.6                0.063
#
#    Local tax rate  Total rate  Median Income  AvgTuition  Rank_Unemployment  \
# 0           0.049       0.089        59345.0     10309.0               30.0
# 1           0.020       0.083        65886.0      8729.0                4.0
# 2           0.000       0.060        50492.0     12273.0               34.5
# 3           0.060       0.100            NaN         NaN                NaN
# 4           0.000       0.063        62180.0     20442.0                6.0
#
#    Rank_Sales  Rank_income  Rank_Tution
# 0        44.5         22.0         15.0
# 1        27.5         29.0         21.5
# 2         4.5         10.0         10.0
# 3        47.0          NaN          NaN
# 4         4.5         25.0          1.0

# %%
economy['Rank_Unemployment'].fillna(economy['Rank_Unemployment'].max() + 1, inplace=True)
economy['Rank_Sales'].fillna(economy['Rank_Sales'].max() + 1, inplace=True)
economy['Rank_income'].fillna(economy['Rank_income'].max() + 1, inplace=True)
economy['Rank_Tution'].fillna(economy['Rank_Tution'].max() + 1, inplace=True)

# %%
economy['Sum'] = (economy['Rank_Unemployment'] + economy['Rank_Sales'] + 
                  economy['Rank_income'] + economy['Rank_Tution'])

# %%
economy.dtypes
# Out:
# City                     object
# State                    object
# Percent unemployment    float64
# State sale tax rate     float64
# Local tax rate          float64
# Total rate              float64
# Median Income           float64
# AvgTuition              float64
# Rank_Unemployment       float64
# Rank_Sales              float64
# Rank_income             float64
# Rank_Tution             float64
# Sum                     float64
# Economy_rank            float64
# dtype: object

# %%
economy['Economy_rank'] = economy['Sum'].rank(ascending = 0)

# %%
economy
# Out:
#               City State  Percent unemployment  State sale tax rate  \
# 0          Atlanta    GA                  10.2                0.040
# 1           Austin    TX                   6.3                0.063
# 2        Baltimore    MD                  11.1                0.060
# 3       Birmingham    AL                   NaN                4.050
# 4           Boston    MA                   6.6                0.063
# 5          Buffalo    NY                   NaN                0.040
# 6        Charlotte    NC                   9.9                0.048
# 7          Chicago    IL                   9.8                0.063
# 8       Cincinnati    OH                   7.2                0.058
# 9        Cleveland    OH                   7.9                0.058
# 10        Columbus    OH                   6.5                0.058
# 11          Dallas    TX                   7.9                0.063
# 12          Denver    CO                   8.9                0.029
# 13         Detroit    MI                   NaN                0.060
# 14        Hartford    CT                   NaN                  NaN
# 15         Houston    TX                   7.6                0.063
# 16    Indianapolis    IN                   8.9                0.070
# 17    Jacksonville    FL                   NaN                0.060
# 18     Kansas City    MO                   6.9                0.042
# 19       Las Vegas    NV                   NaN                0.069
# 20     Los Angeles    CA                  11.1                0.073
# 21      Louisville    KY                   NaN                0.060
# 22         Memphis    TN                   NaN                0.070
# 23           Miami    FL                   NaN                0.060
# 24       Milwaukee    WI                   9.4                0.050
# 25     Minneapolis    MN                   5.7                0.069
# 26       Nashville    TN                   7.3                0.070
# 27     New Orleans    LA                  10.6                0.050
# 28        New York    NY                  11.0                0.040
# 29   Oklahoma City    OK                   5.2                0.045
# 30         Orlando    FL                   NaN                0.060
# 31    Philadelphia    PA                  10.9                0.060
# 32         Phoenix    AZ                   7.3                0.056
# 33      Pittsburgh    PA                   7.0                0.060
# 34        Portland    OR                   7.9                0.000
# 35      Providence    RI                   NaN                  NaN
# 36        Richmond    VA                   NaN                0.053
# 37       Riverside    CA                   NaN                0.073
# 38       Rochester    NY                   8.4                0.040
# 39      Sacramento    CA                   NaN                0.073
# 40  Salt Lake City    UT                   NaN                  NaN
# 41     San Antonio    TX                   7.4                0.063
# 42       San Diego    CA                   9.2                0.073
# 43   San Francisco    CA                   7.8                0.073
# 44        San Jose    CA                   8.7                0.073
# 45         Seattle    WA                   7.2                0.065
# 46       St. Louis    MO                   9.8                0.042
# 47           Tampa    FL                   8.8                0.060
# 48  Virginia Beach    VA                   5.7                0.053
# 49      Washington    DC                   9.1                0.058
#
#     Local tax rate  Total rate  Median Income  AvgTuition  Rank_Unemployment  \
# 0            0.049       0.089        59345.0     10309.0               30.0
# 1            0.020       0.083        65886.0      8729.0                4.0
# 2            0.000       0.060        50492.0     12273.0               34.5
# 3            0.060       0.100            NaN         NaN               35.5
# 4            0.000       0.063        62180.0     20442.0                6.0
# 5            0.048       0.088            NaN     16305.0               35.5
# 6            0.025       0.073        65622.0         NaN               29.0
# 7            0.040       0.103        56121.0      7844.0               27.5
# 8            0.013       0.070        49048.0      6304.0                9.5
# 9            0.023       0.080        35685.0      6304.0               17.0
# 10           0.018       0.075        54763.0      6304.0                5.0
# 11           0.020       0.083        44838.0      8729.0               17.0
# 12           0.048       0.077        59155.0     10468.0               22.5
# 13           0.000       0.060            NaN      6791.0               35.5
# 14             NaN         NaN            NaN         NaN               35.5
# 15           0.020       0.083        48889.0      8729.0               14.0
# 16           0.000       0.070        56862.0      6515.0               22.5
# 17           0.010       0.070            NaN      7996.0               35.5
# 18           0.041       0.083        59980.0      9497.0                7.0
# 19           0.013       0.082            NaN      9687.0               35.5
# 20           0.020       0.093        56558.0     13277.0               34.5
# 21           0.000       0.060            NaN         NaN               35.5
# 22           0.023       0.093            NaN      8759.0               35.5
# 23           0.010       0.070            NaN      7996.0               35.5
# 24           0.006       0.056        44113.0      4357.0               26.0
# 25           0.009       0.078        64095.0      6656.0                2.5
# 26           0.023       0.093        59270.0         NaN               11.5
# 27           0.050       0.100        48789.0      6125.0               31.0
# 28           0.049       0.089        58608.0     16305.0               33.0
# 29           0.039       0.084        58370.0      5464.0                1.0
# 30           0.005       0.065            NaN      7996.0               35.5
# 31           0.020       0.080        48330.0     10852.0               32.0
# 32           0.030       0.086        60366.0     10492.0               11.5
# 33           0.010       0.070        51907.0     10852.0                8.0
# 34           0.000       0.000        65554.0         NaN               17.0
# 35             NaN         NaN            NaN         NaN               35.5
# 36           0.000       0.053            NaN         NaN               35.5
# 37           0.005       0.078            NaN         NaN               35.5
# 38           0.040       0.080        37111.0         NaN               19.0
# 39           0.010       0.083            NaN     13277.0               35.5
# 40             NaN         NaN            NaN         NaN               35.5
# 41           0.020       0.083        54444.0      8729.0               13.0
# 42           0.005       0.078        79269.0     13277.0               25.0
# 43           0.013       0.085        90640.0     13277.0               15.0
# 44           0.015       0.088        92539.0     13277.0               20.0
# 45           0.031       0.096        90303.0      9929.0                9.5
# 46           0.045       0.087        44360.0         NaN               27.5
# 47           0.010       0.070        55039.0      7996.0               21.0
# 48           0.007       0.060        76637.0     13255.0                2.5
# 49           0.000       0.058        72110.0         NaN               24.0
#
#     Rank_Sales  Rank_income  Rank_Tution    Sum  Economy_rank
# 0         44.5         22.0         15.0  111.5          37.0
# 1         27.5         29.0         21.5   82.0          17.0
# 2          4.5         10.0         10.0   59.0           4.0
# 3         47.0         36.0         38.0  156.5          47.0
# 4          4.5         25.0          1.0   36.5           1.0
# 5         42.5         36.0          2.5  116.5          42.0
# 6         34.0         28.0         38.0  129.0          46.0
# 7         38.5         15.0         28.0  109.0          34.0
# 8         21.0          9.0         33.0   72.5           7.5
# 9         32.0          1.0         33.0   83.0          18.0
# 10        24.0         13.0         33.0   75.0          11.5
# 11        27.5          5.0         21.5   71.0           5.5
# 12        42.5         20.0         14.0   99.0          29.5
# 13         4.5         36.0         29.0  105.0          32.0
# 14        48.0         36.0         38.0  157.5          49.0
# 15        27.5          8.0         21.5   71.0           5.5
# 16         4.5         17.0         31.0   75.0          11.5
# 17        17.0         36.0         25.5  114.0          39.5
# 18        40.0         23.0         18.0   88.0          23.0
# 19        21.0         36.0         17.0  109.5          35.0
# 20        27.5         16.0          6.0   84.0          20.5
# 21         4.5         36.0         38.0  114.0          39.5
# 22        32.0         36.0         19.0  122.5          45.0
# 23        17.0         36.0         25.5  114.0          39.5
# 24        12.0          3.0         37.0   78.0          16.0
# 25        14.0         26.0         30.0   72.5           7.5
# 26        32.0         21.0         38.0  102.5          31.0
# 27        46.0          7.0         35.0  119.0          43.0
# 28        44.5         19.0          2.5   99.0          29.5
# 29        37.0         18.0         36.0   92.0          24.0
# 30        10.0         36.0         25.5  107.0          33.0
# 31        27.5          6.0         11.5   77.0          14.0
# 32        35.0         24.0         13.0   83.5          19.0
# 33        17.0         11.0         11.5   47.5           2.0
# 34         4.5         27.0         38.0   86.5          22.0
# 35        48.0         36.0         38.0  157.5          49.0
# 36         4.5         36.0         38.0  114.0          39.5
# 37        10.0         36.0         38.0  119.5          44.0
# 38        38.5          2.0         38.0   97.5          28.0
# 39        17.0         36.0          6.0   94.5          25.5
# 40        48.0         36.0         38.0  157.5          49.0
# 41        27.5         12.0         21.5   74.0          10.0
# 42        10.0         32.0          6.0   73.0           9.0
# 43        21.0         34.0          6.0   76.0          13.0
# 44        23.0         35.0          6.0   84.0          20.5
# 45        36.0         33.0         16.0   94.5          25.5
# 46        41.0          4.0         38.0  110.5          36.0
# 47        17.0         14.0         25.5   77.5          15.0
# 48        13.0         31.0          9.0   55.5           3.0
# 49         4.5         30.0         38.0   96.5          27.0

# %%
economy.to_csv('Economy_Rank.csv')

# %%
#Basic Graph Analysis
# %matplotlib inline  
plt.scatter(economy['Local tax rate'],economy['Economy_rank'])

# %%
plt.scatter(economy['Median Income'], economy['Economy_rank'])

# %%
#Get the Geodata
import pandas as pd
from geopy.geocoders import Nominatim
geolocator = Nominatim()
n = len(economy)
cname = []
for i in range(0, n):
    cname.append(economy['City'][i])
b = []
c = []
for j in range(0, n):
    city = cname[j] 
    loc = geolocator.geocode(city + ' United States')
    b.append(loc.latitude)
    c.append(loc.longitude)
economy['Lat'] = b
economy['Lon'] = c
economy.to_csv('economy_loc.csv')

# %%
#Geo plotting
import plotly
import plotly.plotly as py
import pandas as pd

df = economy
df.head()

# df['text'] = df['name'] + '<br>Population ' + (df['pop']/1e6).astype(str)+' million'
limits = [(0,2),(3,10),(11,20),(21,50),(50,3000)]
colors = ["rgb(0,116,217)","rgb(255,65,54)","rgb(133,20,75)","rgb(255,133,27)","lightgrey"]
cities = []
scale = 5000

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = economy['Lon'],
        lat = economy['Lat'],
        text = economy['City'],
        marker = dict(
            size = economy['Sum']*10,
            color = colors[i],
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)

layout = dict(
        title = '2014 US city populations<br>(Click legend to toggle traces)',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),
    )

fig = dict( data=cities, layout=layout )
plotly.offline.plot( fig, validate=False, filename='d3-bubble-map-populations.html' )
# Out:
# 'file://C:\\Users\\dell\\Documents\\cse583\\Homework\\d3-bubble-map-populations.html'
